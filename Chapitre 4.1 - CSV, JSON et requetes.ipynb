# %% [markdown]
# # Chapitre 4.1 - Les fichiers CSV, JSON et les requêtes

# %% [markdown]
# ## Le format CSV
#
# Un fichier CSV est un fichier de tableau simplifié au maximum :
# - le fichier est encodé en plein texte, il peut être lu par un éditeur de texte lambda
# - le fichier utilise un séparateur de colonnes (usuellement une virgule, un point-virgule ou une tabulation)
# - le fichier utilise une ligne par ligne de tableur
#
# Exemple : [Les 1000 premiers numéros du Gaulois en statistiques](./data/csv/gaulois.csv) (grâce à la [BNF](http://api.bnf.fr/m%C3%A9tadonn%C3%A9es-quantitatives-de-la-presse-ancienne-xixe-xxe-si%C3%A8cles#chapitre3) )

# %% [markdown]
# ## Les Packages
#
# Python est fait de nombreuses fonctions de bases. Nous avons vu par exemple qu'il était possible d'utiliser facilement les fonctions `len()` ou encore `print()`. Mais Python possède aussi des `packages` (le nom des librairies et bibliothèques en Python) par défaut.
#
# Un package est un ensemble de modules comportant des outils tels que des fonctions et qui peut être assez simplement importé. Par exemple, si je voulais travailler avec le package standard pour utiliser des fichiers CSV, je ferais :

# %%
import csv

# %% [markdown]
# Cette ligne va me permettre d'importer le module csv. Regardons ce qu'il a dans le ventre :

# %%
dir(csv)
# Out:
# ['Dialect',
#  'DictReader',
#  'DictWriter',
#  'Error',
#  'OrderedDict',
#  'QUOTE_ALL',
#  'QUOTE_MINIMAL',
#  'QUOTE_NONE',
#  'QUOTE_NONNUMERIC',
#  'Sniffer',
#  'StringIO',
#  '_Dialect',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'excel',
#  'excel_tab',
#  'field_size_limit',
#  'get_dialect',
#  'list_dialects',
#  're',
#  'reader',
#  'register_dialect',
#  'unix_dialect',
#  'unregister_dialect',
#  'writer']

# %% [markdown]
# C'est bien, mais ça ne vous dit pas grand-chose non ? On voit à la limite quelque chose pour lire (`reader`) et quelque chose pour écrire (`writer`) avec *a priori* deux variations : `DictReader` et `DictWriter`. Mais cela reste vague.

# %% [markdown]
# ---
#
# ## Le package CSV
#
# Heureusement, python propose pour ses librairies standards une très bonne documentation : https://docs.python.org/3.5/library/csv.html
#
# Je reprends ci-dessous deux morceaux de la documentation, qui sont ceux qui vont d'abord nous intéresser.
#
# ### 1. Lire
#
# Commençons par ce qui est la documentation de `reader()`
#
# #### csv.reader(csvfile, dialect=’excel’, **fmtparams)
#
# > Return a reader object which will iterate over lines in the given `csvfile`. `csvfile` can be any object which supports the iterator protocol and returns a string each time its `__next__()` method is called — file objects and list objects are both suitable. If csvfile is a file object, it should be opened with newline=''. [1] An optional `dialect` parameter can be given which is used to define a set of parameters specific to a particular CSV dialect. It may be an instance of a subclass of the Dialect class or one of the strings returned by the list_dialects() function. The other optional `fmtparams` keyword arguments can be given to override individual formatting parameters in the current dialect. For full details about the dialect and formatting parameters, see section [Dialects and Formatting Parameters](https://docs.python.org/3.5/library/csv.html#dialects-and-formatting-parameters).
#
# > Each row read from the csv file is returned as a list of strings. No automatic data type conversion is performed unless the QUOTE_NONNUMERIC format option is specified (in which case unquoted fields are transformed into floats).
#
# > A short usage example:

# %%
import csv
with open('data/csv/eggs.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        #print(row)
        print(', '.join(row))
# Spam, Spam, Spam, Spam, Spam, Baked Beans
# Spam, Lovely Spam, Wonderful Spam
# Out:
# Spam, Spam, Spam, Spam, Spam, Baked Beans
# Spam, Lovely Spam, Wonderful Spam

# %% [markdown]
# **À partir de cette documentation et de cet exemple**, on peut tirer plusieurs conclusions :
#
# - `csv.reader()` prend comme premier argument un fichier ouvert
# - il peut prendre un `dialect` ou des paramètres qui ne sont pas développés par la documentation de la fonction elle-même : dans `**fmtparams`, `**` signifie qu'il existe d'autres paramètres optionnels nominatifs.
# - il arrive que, sans aller dans *Dialects and Formatting Parameters*, nous avons deux exemples de ces paramètres dans l'exemple :
#     - `delimiter` qui semble être un délimiteur de colonne.
#     - `quotechar` qui semble être un "encapsulateur" permettant d'échapper les délimiteurs
#
# Regardons le fichier [data/csv/eggs.csv](data/csv/eggs.csv)
#
# En lançant l'exemple, on s'aperçoit que le `reader` va renvoyer une liste quand on va itérer dessus: ces listes correspondent aux lignes.

# %% [markdown]
# ###### Une fonction utile : la fonction enumerate
#
# Dans le cadre d'une boucle, enumerate permet de renvoyer un tuple sur une valeur simple afin de de compter l'index de l'objet parcouru :

# %%
couleurs = ["vert", "rouge", "bleu"]

for index, couleur in enumerate(couleurs):
    print(str(index)+ " = " + couleur)
# Out:
# 0 = vert
# 1 = rouge
# 2 = bleu

# %% [markdown]
# ##### Exercice
#
# À partir du fichier `data/csv/gaulois.csv`, compter le nombre de publicités en page 1 sur l'ensemble des numéros.
#
# *Attention ! La première ligne est une ligne d'en-tête*

# %%
pubs = 0
with open("data/csv/gaulois.csv", "r", encoding="UTF-8") as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    next(reader) # permet de sauter le header
    for r in reader:
        pubs += int(r[9])
print(pubs)   

# Tests pour vérifier : le résultat doit être enregistré dans une variable pubs
assert pubs == 2260, "Il y a eu 2260 publicité sur les premiers numéros du Gaulois"
# Out:
# 2260

# %% [markdown]
# ### 2. Écrire
#
# Si lire est utile, écrire l'est tout autant, surtout lorsque l'on récupère des informations d'ici et là et que l'on veut les remettre en formes
#
# Voyons la documentation de csv.writer et son exemple :
#
# #### csv.writer(csvfile, dialect=’excel’, **fmtparams)
#
# >    Return a writer object responsible for converting the user’s data into delimited strings on the given file-like object. csvfile can be any object with a write() method. If csvfile is a file object, it should be opened with newline='' [1]. An optional dialect parameter can be given which is used to define a set of parameters specific to a particular CSV dialect. It may be an instance of a subclass of the Dialect class or one of the strings returned by the list_dialects() function. The other optional fmtparams keyword arguments can be given to override individual formatting parameters in the current dialect. For full details about the dialect and formatting parameters, see section Dialects and Formatting Parameters. To make it as easy as possible to interface with modules which implement the DB API, the value None is written as the empty string. While this isn’t a reversible transformation, it makes it easier to dump SQL NULL data values to CSV files without preprocessing the data returned from a cursor.fetch* call. All other non-string data are stringified with str() before being written.
#
# > A short usage example:

# %%
import csv
with open('data/csv/eggs.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
    spamwriter.writerow(['Spam', 'Lovely Spam', 'Wonderful Spam'])

# %% [markdown]
# **À partir de cette documentation et de cet exemple**, on peut tirer plusieurs conclusions :
#
# - `csv.writer()` prend comme premier argument un fichier ouvert en mode écriture
# - il peut prendre un `dialect` ou des paramètres qui ne sont pas développés par la documentation de la fonction elle-même : dans `**fmtparams`, `**` signifie qu'il existe d'autres paramètres optionnels nominatifs.
# - il arrive que, sans aller dans *Dialects and Formatting Parameters*, nous ayons deux exemples de ces paramètres dans l'exemple :
#     - `delimiter` qui semble être un délimiteur de colonne.
#     - `quotechar` qui semble être un "encapsulateur" permettant d'échapper les délimiteurs
#     - `quoting` qui d'après la documentation correspond à un mode de citation minimal (Utilisation des `quotechar` que lorsque cela est nécessaire. C'est par ailleurs la valeur par défaut : https://docs.python.org/3.5/library/csv.html#csv.Dialect.quoting )
# - on écrit une ligne en utilisant la méthode `.writerow()` qui prend comme argument une liste
# - on utilise `.writerow()` autant de fois que nécessaire
#
# Regardons le fichier [data/csv/eggs.csv](data/csv/eggs.csv)
#
# En lançant l'exemple, on s'aperçoit que le `writer()` va rédiger deux lignes. Ce sont les deux que nous avons lues plus haut.

# %% [markdown]
# ##### Exercice
#
# `modules_cours.chapitre4` est un module écrit spécifiquement pour ce cours (si vous êtes [curieux-ses](modules_cours/chapitre4.py)) Dans ce module, il y a la fonction `read_rss()` qui renvoie un générateur contenant des tuples Titre - Résumé - Lien - Date de publication. Par exemple :

# %%
from modules_cours.chapitre4 import read_rss

# Il s'agit ici de l'adresse RSS d'un flux de la BNF
for entree in read_rss("http://www.bnf.fr/Satellite?c=Page&cid=1237374444944&locale=1194947514616&p=1237374444944&pagename=bnf_dev%2FRss&typeRss=Biblio"):
    print(entree)

# %% [markdown]
# À partir de cette fonction, réaliser un CSV (en utilisant le délimiteur `\t`) pour le flux RSS de Bibliopat : `http://www.bibliopat.fr/rss-actualites`. Le CSV sera stocké à `bibliopat.csv`.

# %%
from modules_cours.chapitre4 import read_rss
import csv

# Votre code ici

# %% [markdown]
# ##### Avez-vous remarqué ?
#
# Ci-dessus, nous avons utilisé `from ___ import ___`. Cette structure d'import nous permet de n'importer qu'un sous-module ou une sous-fonction en particulier. Très pratique pour éviter les noms à rallonge !

# %% [markdown]
# ----
#
# #### Ce que l'on a appris
#
# Pour finir cette section, voici un récapitulatif des concepts appris. Lisez la liste et posez des questions si certaines choses ne sont pas claires.
#
# - `import`
# - `from ___ import ___`
# - la notion de librairie/module/package
# - `csv.reader()`
# - `csv.writer()`
# - `enumerate()`
# - Lire une documentation et ses exemples
#
# #### Ce que l'on recommande d'approfondir
#
# Si les fonctions `csv.reader()` et `csv.writer()` sont sympathiques, les fonctions `DictReader` et `DictWriter` le sont beaucoup plus : elles stockent les noms de colonnes ! *cf.* [la documentation](https://docs.python.org/3.5/library/csv.html#csv.DictReader)

# %%
with open("data/csv/gaulois.csv", "r", encoding="UTF-8") as csvfile:
    reader = csv.DictReader(csvfile, delimiter=',', quotechar='"')
    for row in reader:
        text = f"La publication date du {row['Publication Date']} et comprend {row['Pages']} pages."
        print(text)
# Out:
# La publication date du 05.07.1868 et comprend 4 pages.
# La publication date du 06.07.1868 et comprend 4 pages.
# La publication date du 07.07.1868 et comprend 4 pages.
# La publication date du 08.07.1868 et comprend 4 pages.
# La publication date du 09.07.1868 et comprend 4 pages.
# La publication date du 10.07.1868 et comprend 4 pages.
# La publication date du 11.07.1868 et comprend 4 pages.
# La publication date du 12.07.1868 et comprend 4 pages.
# La publication date du 13.07.1868 et comprend 4 pages.
# La publication date du 14.07.1868 et comprend 4 pages.
# La publication date du 15.07.1868 et comprend 4 pages.
# La publication date du 16.07.1868 et comprend 4 pages.
# La publication date du 17.07.1868 et comprend 4 pages.
# La publication date du 18.07.1868 et comprend 4 pages.
# La publication date du 19.07.1868 et comprend 4 pages.
# La publication date du 20.07.1868 et comprend 4 pages.
# La publication date du 21.07.1868 et comprend 4 pages.
# La publication date du 22.07.1868 et comprend 4 pages.
# La publication date du 23.07.1868 et comprend 4 pages.
# La publication date du 24.07.1868 et comprend 4 pages.
# La publication date du 25.07.1868 et comprend 4 pages.
# La publication date du 26.07.1868 et comprend 4 pages.
# La publication date du 27.07.1868 et comprend 4 pages.
# La publication date du 28.07.1868 et comprend 4 pages.
# La publication date du 29.07.1868 et comprend 4 pages.
# La publication date du 30.07.1868 et comprend 4 pages.
# La publication date du 31.07.1868 et comprend 4 pages.
# La publication date du 01.08.1868 et comprend 4 pages.
# La publication date du 02.08.1868 et comprend 4 pages.
# La publication date du 03.08.1868 et comprend 4 pages.
# La publication date du 04.08.1868 et comprend 4 pages.
# La publication date du 05.08.1868 et comprend 4 pages.
# La publication date du 06.08.1868 et comprend 4 pages.
# La publication date du 07.08.1868 et comprend 4 pages.
# La publication date du 08.08.1868 et comprend 4 pages.
# La publication date du 09.08.1868 et comprend 4 pages.
# La publication date du 10.08.1868 et comprend 4 pages.
# La publication date du 11.08.1868 et comprend 4 pages.
# La publication date du 12.08.1868 et comprend 4 pages.
# La publication date du 13.08.1868 et comprend 4 pages.
# La publication date du 14.08.1868 et comprend 4 pages.
# La publication date du 15.08.1868 et comprend 4 pages.
# La publication date du 16.08.1868 et comprend 4 pages.
# La publication date du 17.08.1868 et comprend 4 pages.
# La publication date du 18.08.1868 et comprend 4 pages.
# La publication date du 19.08.1868 et comprend 4 pages.
# La publication date du 20.08.1868 et comprend 4 pages.
# La publication date du 21.08.1868 et comprend 4 pages.
# La publication date du 22.08.1868 et comprend 4 pages.
# La publication date du 23.08.1868 et comprend 4 pages.
# La publication date du 24.08.1868 et comprend 4 pages.
# La publication date du 25.08.1868 et comprend 4 pages.
# La publication date du 26.08.1868 et comprend 4 pages.
# La publication date du 27.08.1868 et comprend 4 pages.
# La publication date du 28.08.1868 et comprend 4 pages.
# La publication date du 29.08.1868 et comprend 4 pages.
# La publication date du 30.08.1868 et comprend 4 pages.
# La publication date du 31.08.1868 et comprend 4 pages.
# La publication date du 01.09.1868 et comprend 4 pages.
# La publication date du 02.09.1868 et comprend 4 pages.
# La publication date du 03.09.1868 et comprend 4 pages.
# La publication date du 04.09.1868 et comprend 4 pages.
# La publication date du 05.09.1868 et comprend 4 pages.
# La publication date du 06.09.1868 et comprend 4 pages.
# La publication date du 07.09.1868 et comprend 4 pages.
# La publication date du 08.09.1868 et comprend 4 pages.
# La publication date du 09.09.1868 et comprend 4 pages.
# La publication date du 10.09.1868 et comprend 4 pages.
# La publication date du 11.09.1868 et comprend 4 pages.
# La publication date du 12.09.1868 et comprend 4 pages.
# La publication date du 13.09.1868 et comprend 4 pages.
# La publication date du 14.09.1868 et comprend 4 pages.
# La publication date du 15.09.1868 et comprend 4 pages.
# La publication date du 16.09.1868 et comprend 4 pages.
# La publication date du 17.09.1868 et comprend 4 pages.
# La publication date du 18.09.1868 et comprend 4 pages.
# La publication date du 19.09.1868 et comprend 4 pages.
# La publication date du 20.09.1868 et comprend 4 pages.
# La publication date du 21.09.1868 et comprend 4 pages.
# La publication date du 22.09.1868 et comprend 4 pages.
# La publication date du 23.09.1868 et comprend 4 pages.
# La publication date du 24.09.1868 et comprend 4 pages.
# La publication date du 25.09.1868 et comprend 4 pages.
# La publication date du 26.09.1868 et comprend 4 pages.
# La publication date du 27.09.1868 et comprend 4 pages.
# La publication date du 28.09.1868 et comprend 4 pages.
# La publication date du 29.09.1868 et comprend 4 pages.
# La publication date du 30.09.1868 et comprend 4 pages.
# La publication date du 01.10.1868 et comprend 4 pages.
# La publication date du 02.10.1868 et comprend 4 pages.
# La publication date du 03.10.1868 et comprend 4 pages.
# La publication date du 04.10.1868 et comprend 4 pages.
# La publication date du 05.10.1868 et comprend 4 pages.
# La publication date du 06.10.1868 et comprend 4 pages.
# La publication date du 07.10.1868 et comprend 4 pages.
# La publication date du 08.10.1868 et comprend 4 pages.
# La publication date du 09.10.1868 et comprend 4 pages.
# La publication date du 10.10.1868 et comprend 4 pages.
# La publication date du 11.10.1868 et comprend 4 pages.
# La publication date du 12.10.1868 et comprend 4 pages.
# La publication date du 13.10.1868 et comprend 4 pages.
# La publication date du 14.10.1868 et comprend 4 pages.
# La publication date du 15.10.1868 et comprend 4 pages.
# La publication date du 16.10.1868 et comprend 4 pages.
# La publication date du 17.10.1868 et comprend 4 pages.
# La publication date du 18.10.1868 et comprend 4 pages.
# La publication date du 19.10.1868 et comprend 4 pages.
# La publication date du 20.10.1868 et comprend 4 pages.
# La publication date du 21.10.1868 et comprend 4 pages.
# La publication date du 22.10.1868 et comprend 4 pages.
# La publication date du 23.10.1868 et comprend 4 pages.
# La publication date du 24.10.1868 et comprend 4 pages.
# La publication date du 25.10.1868 et comprend 4 pages.
# La publication date du 26.10.1868 et comprend 4 pages.
# La publication date du 27.10.1868 et comprend 4 pages.
# La publication date du 28.10.1868 et comprend 4 pages.
# La publication date du 29.10.1868 et comprend 4 pages.
# La publication date du 30.10.1868 et comprend 4 pages.
# La publication date du 31.10.1868 et comprend 4 pages.
# La publication date du 01.11.1868 et comprend 4 pages.
# La publication date du 02.11.1868 et comprend 4 pages.
# La publication date du 03.11.1868 et comprend 4 pages.
# La publication date du 04.11.1868 et comprend 4 pages.
# La publication date du 05.11.1868 et comprend 4 pages.
# La publication date du 06.11.1868 et comprend 4 pages.
# La publication date du 07.11.1868 et comprend 4 pages.
# La publication date du 08.11.1868 et comprend 4 pages.
# La publication date du 09.11.1868 et comprend 4 pages.
# La publication date du 10.11.1868 et comprend 4 pages.
# La publication date du 11.11.1868 et comprend 4 pages.
# La publication date du 12.11.1868 et comprend 4 pages.
# La publication date du 13.11.1868 et comprend 4 pages.
# La publication date du 14.11.1868 et comprend 4 pages.
# La publication date du 15.11.1868 et comprend 4 pages.
# La publication date du 16.11.1868 et comprend 4 pages.
# La publication date du 17.11.1868 et comprend 4 pages.
# La publication date du 18.11.1868 et comprend 4 pages.
# La publication date du 19.11.1868 et comprend 4 pages.
# La publication date du 20.11.1868 et comprend 4 pages.
# La publication date du 21.11.1868 et comprend 4 pages.
# La publication date du 22.11.1868 et comprend 4 pages.
# La publication date du 23.11.1868 et comprend 4 pages.
# La publication date du 24.11.1868 et comprend 4 pages.
# La publication date du 25.11.1868 et comprend 4 pages.
# La publication date du 26.11.1868 et comprend 4 pages.
# La publication date du 27.11.1868 et comprend 4 pages.
# La publication date du 28.11.1868 et comprend 4 pages.
# La publication date du 29.11.1868 et comprend 4 pages.
# La publication date du 30.11.1868 et comprend 4 pages.
# La publication date du 01.12.1868 et comprend 4 pages.
# La publication date du 02.12.1868 et comprend 4 pages.
# La publication date du 03.12.1868 et comprend 4 pages.
# La publication date du 04.12.1868 et comprend 4 pages.
# La publication date du 05.12.1868 et comprend 4 pages.
# La publication date du 06.12.1868 et comprend 4 pages.
# La publication date du 07.12.1868 et comprend 4 pages.
# La publication date du 08.12.1868 et comprend 4 pages.
# La publication date du 09.12.1868 et comprend 4 pages.
# La publication date du 10.12.1868 et comprend 4 pages.
# La publication date du 11.12.1868 et comprend 4 pages.
# La publication date du 12.12.1868 et comprend 4 pages.
# La publication date du 13.12.1868 et comprend 4 pages.
# La publication date du 14.12.1868 et comprend 4 pages.
# La publication date du 15.12.1868 et comprend 4 pages.
# La publication date du 16.12.1868 et comprend 4 pages.
# La publication date du 17.12.1868 et comprend 4 pages.
# La publication date du 18.12.1868 et comprend 4 pages.
# La publication date du 19.12.1868 et comprend 4 pages.
# La publication date du 20.12.1868 et comprend 4 pages.
# La publication date du 21.12.1868 et comprend 4 pages.
# La publication date du 22.12.1868 et comprend 4 pages.
# La publication date du 23.12.1868 et comprend 4 pages.
# La publication date du 24.12.1868 et comprend 4 pages.
# La publication date du 25.12.1868 et comprend 4 pages.
# La publication date du 26.12.1868 et comprend 4 pages.
# La publication date du 27.12.1868 et comprend 4 pages.
# La publication date du 28.12.1868 et comprend 4 pages.
# La publication date du 29.12.1868 et comprend 4 pages.
# La publication date du 30.12.1868 et comprend 4 pages.
# La publication date du 31.12.1868 et comprend 4 pages.
# La publication date du 01.01.1869 et comprend 4 pages.
# La publication date du 02.01.1869 et comprend 4 pages.
# La publication date du 03.01.1869 et comprend 4 pages.
# La publication date du 04.01.1869 et comprend 4 pages.
# La publication date du 05.01.1869 et comprend 4 pages.
# La publication date du 06.01.1869 et comprend 4 pages.
# La publication date du 07.01.1869 et comprend 4 pages.
# La publication date du 08.01.1869 et comprend 4 pages.
# La publication date du 09.01.1869 et comprend 4 pages.
# La publication date du 10.01.1869 et comprend 4 pages.
# La publication date du 11.01.1869 et comprend 4 pages.
# La publication date du 12.01.1869 et comprend 4 pages.
# La publication date du 13.01.1869 et comprend 4 pages.
# La publication date du 14.01.1869 et comprend 4 pages.
# La publication date du 15.01.1869 et comprend 4 pages.
# La publication date du 16.01.1869 et comprend 4 pages.
# La publication date du 17.01.1869 et comprend 4 pages.
# La publication date du 18.01.1869 et comprend 4 pages.
# La publication date du 19.01.1869 et comprend 4 pages.
# La publication date du 20.01.1869 et comprend 4 pages.
# La publication date du 21.01.1869 et comprend 4 pages.
# La publication date du 22.01.1869 et comprend 4 pages.
# La publication date du 23.01.1869 et comprend 4 pages.
# La publication date du 24.01.1869 et comprend 4 pages.
# La publication date du 25.01.1869 et comprend 4 pages.
# La publication date du 26.01.1869 et comprend 4 pages.
# La publication date du 27.01.1869 et comprend 4 pages.
# La publication date du 28.01.1869 et comprend 4 pages.
# La publication date du 29.01.1869 et comprend 4 pages.
# La publication date du 30.01.1869 et comprend 4 pages.
# La publication date du 31.01.1869 et comprend 4 pages.
# La publication date du 01.02.1869 et comprend 4 pages.
# La publication date du 02.02.1869 et comprend 4 pages.
# La publication date du 03.02.1869 et comprend 4 pages.
# La publication date du 04.02.1869 et comprend 4 pages.
# La publication date du 05.02.1869 et comprend 4 pages.
# La publication date du 06.02.1869 et comprend 4 pages.
# La publication date du 07.02.1869 et comprend 4 pages.
# La publication date du 08.02.1869 et comprend 4 pages.
# La publication date du 09.02.1869 et comprend 4 pages.
# La publication date du 10.02.1869 et comprend 4 pages.
# La publication date du 11.02.1869 et comprend 4 pages.
# La publication date du 12.02.1869 et comprend 4 pages.
# La publication date du 13.02.1869 et comprend 4 pages.
# La publication date du 14.02.1869 et comprend 4 pages.
# La publication date du 15.02.1869 et comprend 4 pages.
# La publication date du 16.02.1869 et comprend 4 pages.
# La publication date du 17.02.1869 et comprend 4 pages.
# La publication date du 18.02.1869 et comprend 4 pages.
# La publication date du 19.02.1869 et comprend 4 pages.
# La publication date du 20.02.1869 et comprend 4 pages.
# La publication date du 21.02.1869 et comprend 4 pages.
# La publication date du 22.02.1869 et comprend 4 pages.
# La publication date du 23.02.1869 et comprend 4 pages.
# La publication date du 24.02.1869 et comprend 4 pages.
# La publication date du 25.02.1869 et comprend 4 pages.
# La publication date du 26.02.1869 et comprend 4 pages.
# La publication date du 27.02.1869 et comprend 4 pages.
# La publication date du 28.02.1869 et comprend 4 pages.
# La publication date du 01.03.1869 et comprend 4 pages.
# La publication date du 02.03.1869 et comprend 4 pages.
# La publication date du 03.03.1869 et comprend 4 pages.
# La publication date du 04.03.1869 et comprend 4 pages.
# La publication date du 05.03.1869 et comprend 4 pages.
# La publication date du 06.03.1869 et comprend 4 pages.
# La publication date du 07.03.1869 et comprend 4 pages.
# La publication date du 08.03.1869 et comprend 4 pages.
# La publication date du 09.03.1869 et comprend 4 pages.
# La publication date du 10.03.1869 et comprend 4 pages.
# La publication date du 11.03.1869 et comprend 4 pages.
# La publication date du 12.03.1869 et comprend 4 pages.
# La publication date du 14.03.1869 et comprend 4 pages.
# La publication date du 15.03.1869 et comprend 4 pages.
# La publication date du 16.03.1869 et comprend 4 pages.
# La publication date du 17.03.1869 et comprend 4 pages.
# La publication date du 18.03.1869 et comprend 4 pages.
# La publication date du 19.03.1869 et comprend 4 pages.
# La publication date du 20.03.1869 et comprend 4 pages.
# La publication date du 21.03.1869 et comprend 4 pages.
# La publication date du 22.03.1869 et comprend 4 pages.
# La publication date du 23.03.1869 et comprend 4 pages.
# La publication date du 24.03.1869 et comprend 4 pages.
# La publication date du 25.03.1869 et comprend 4 pages.
# La publication date du 26.03.1869 et comprend 4 pages.
# La publication date du 27.03.1869 et comprend 4 pages.
# La publication date du 28.03.1869 et comprend 4 pages.
# La publication date du 29.03.1869 et comprend 4 pages.
# La publication date du 31.03.1869 et comprend 4 pages.
# La publication date du 01.04.1869 et comprend 4 pages.
# La publication date du 02.04.1869 et comprend 4 pages.
# La publication date du 03.04.1869 et comprend 4 pages.
# La publication date du 04.04.1869 et comprend 4 pages.
# La publication date du 05.04.1869 et comprend 4 pages.
# La publication date du 06.04.1869 et comprend 4 pages.
# La publication date du 07.04.1869 et comprend 4 pages.
# La publication date du 08.04.1869 et comprend 4 pages.
# La publication date du 09.04.1869 et comprend 4 pages.
# La publication date du 10.04.1869 et comprend 4 pages.
# La publication date du 11.04.1869 et comprend 4 pages.
# La publication date du 12.04.1869 et comprend 4 pages.
# La publication date du 13.04.1869 et comprend 4 pages.
# La publication date du 14.04.1869 et comprend 4 pages.
# La publication date du 15.04.1869 et comprend 4 pages.
# La publication date du 16.04.1869 et comprend 4 pages.
# La publication date du 17.04.1869 et comprend 4 pages.
# La publication date du 18.04.1869 et comprend 4 pages.
# La publication date du 19.04.1869 et comprend 4 pages.
# La publication date du 20.04.1869 et comprend 4 pages.
# La publication date du 21.04.1869 et comprend 4 pages.
# La publication date du 22.04.1869 et comprend 4 pages.
# La publication date du 23.04.1869 et comprend 4 pages.
# La publication date du 24.04.1869 et comprend 4 pages.
# La publication date du 25.04.1869 et comprend 4 pages.
# La publication date du 26.04.1869 et comprend 4 pages.
# La publication date du 27.04.1869 et comprend 4 pages.
# La publication date du 28.04.1869 et comprend 4 pages.
# La publication date du 29.04.1869 et comprend 4 pages.
# La publication date du 30.04.1869 et comprend 4 pages.
# La publication date du 01.05.1869 et comprend 4 pages.
# La publication date du 02.05.1869 et comprend 4 pages.
# La publication date du 03.05.1869 et comprend 4 pages.
# La publication date du 04.05.1869 et comprend 4 pages.
# La publication date du 05.05.1869 et comprend 4 pages.
# La publication date du 06.05.1869 et comprend 4 pages.
# La publication date du 07.05.1869 et comprend 4 pages.
# La publication date du 08.05.1869 et comprend 4 pages.
# La publication date du 09.05.1869 et comprend 4 pages.
# La publication date du 10.05.1869 et comprend 4 pages.
# La publication date du 11.05.1869 et comprend 4 pages.
# La publication date du 12.05.1869 et comprend 4 pages.
# La publication date du 13.05.1869 et comprend 4 pages.
# La publication date du 14.05.1869 et comprend 4 pages.
# La publication date du 15.05.1869 et comprend 4 pages.
# La publication date du 16.05.1869 et comprend 4 pages.
# La publication date du 17.05.1869 et comprend 4 pages.
# La publication date du 18.05.1869 et comprend 4 pages.
# La publication date du 19.05.1869 et comprend 4 pages.
# La publication date du 20.05.1869 et comprend 4 pages.
# La publication date du 21.05.1869 et comprend 4 pages.
# La publication date du 22.05.1869 et comprend 4 pages.
# La publication date du 23.05.1869 et comprend 4 pages.
# La publication date du 24.05.1869 et comprend 4 pages.
# La publication date du 25.05.1869 et comprend 4 pages.
# La publication date du 25.05.1869 et comprend 4 pages.
# La publication date du 26.05.1869 et comprend 4 pages.
# La publication date du 27.05.1869 et comprend 4 pages.
# La publication date du 28.05.1869 et comprend 4 pages.
# La publication date du 29.05.1869 et comprend 4 pages.
# La publication date du 30.05.1869 et comprend 4 pages.
# La publication date du 31.05.1869 et comprend 4 pages.
# La publication date du 01.06.1869 et comprend 4 pages.
# La publication date du 02.06.1869 et comprend 4 pages.
# La publication date du 03.06.1869 et comprend 4 pages.
# La publication date du 04.06.1869 et comprend 4 pages.
# La publication date du 05.06.1869 et comprend 4 pages.
# La publication date du 06.06.1869 et comprend 4 pages.
# La publication date du 07.06.1869 et comprend 4 pages.
# La publication date du 08.06.1869 et comprend 4 pages.
# La publication date du 09.06.1869 et comprend 4 pages.
# La publication date du 10.06.1869 et comprend 4 pages.
# La publication date du 11.06.1869 et comprend 4 pages.
# La publication date du 12.06.1869 et comprend 4 pages.
# La publication date du 13.06.1869 et comprend 4 pages.
# La publication date du 14.06.1869 et comprend 4 pages.
# La publication date du 15.06.1869 et comprend 4 pages.
# La publication date du 16.06.1869 et comprend 4 pages.
# La publication date du 17.06.1869 et comprend 4 pages.
# La publication date du 18.06.1869 et comprend 4 pages.
# La publication date du 19.06.1869 et comprend 4 pages.
# La publication date du 20.06.1869 et comprend 4 pages.
# La publication date du 21.06.1869 et comprend 4 pages.
# La publication date du 22.06.1869 et comprend 4 pages.
# La publication date du 23.06.1869 et comprend 4 pages.
# La publication date du 24.06.1869 et comprend 4 pages.
# La publication date du 25.06.1869 et comprend 4 pages.
# La publication date du 26.06.1869 et comprend 4 pages.
# La publication date du 27.06.1869 et comprend 4 pages.
# La publication date du 28.06.1869 et comprend 4 pages.
# La publication date du 29.06.1869 et comprend 4 pages.
# La publication date du 30.06.1869 et comprend 4 pages.
# La publication date du 01.07.1869 et comprend 4 pages.
# La publication date du 02.07.1869 et comprend 4 pages.
# La publication date du 03.07.1869 et comprend 4 pages.
# La publication date du 04.07.1869 et comprend 4 pages.
# La publication date du 05.07.1869 et comprend 4 pages.
# La publication date du 06.07.1869 et comprend 4 pages.
# La publication date du 07.07.1869 et comprend 4 pages.
# La publication date du 08.07.1869 et comprend 4 pages.
# La publication date du 09.07.1869 et comprend 4 pages.
# La publication date du 10.07.1869 et comprend 4 pages.
# La publication date du 11.07.1869 et comprend 4 pages.
# La publication date du 12.07.1869 et comprend 4 pages.
# La publication date du 13.07.1869 et comprend 4 pages.
# La publication date du 14.07.1869 et comprend 4 pages.
# La publication date du 15.07.1869 et comprend 4 pages.
# La publication date du 16.07.1869 et comprend 4 pages.
# La publication date du 17.07.1869 et comprend 4 pages.
# La publication date du 18.07.1869 et comprend 4 pages.
# La publication date du 19.07.1869 et comprend 4 pages.
# La publication date du 20.07.1869 et comprend 4 pages.
# La publication date du 21.07.1869 et comprend 4 pages.
# La publication date du 22.07.1869 et comprend 4 pages.
# La publication date du 23.07.1869 et comprend 4 pages.
# La publication date du 24.07.1869 et comprend 4 pages.
# La publication date du 25.07.1869 et comprend 4 pages.
# La publication date du 26.07.1869 et comprend 4 pages.
# La publication date du 27.07.1869 et comprend 4 pages.
# La publication date du 28.07.1869 et comprend 4 pages.
# La publication date du 29.07.1869 et comprend 4 pages.
# La publication date du 30.07.1869 et comprend 4 pages.
# La publication date du 31.07.1869 et comprend 4 pages.
# La publication date du 01.08.1869 et comprend 4 pages.
# La publication date du 02.08.1869 et comprend 4 pages.
# La publication date du 03.08.1869 et comprend 4 pages.
# La publication date du 04.08.1869 et comprend 4 pages.
# La publication date du 05.08.1869 et comprend 4 pages.
# La publication date du 06.08.1869 et comprend 4 pages.
# La publication date du 07.08.1869 et comprend 4 pages.
# La publication date du 08.08.1869 et comprend 4 pages.
# La publication date du 09.08.1869 et comprend 4 pages.
# La publication date du 10.08.1869 et comprend 4 pages.
# La publication date du 11.08.1869 et comprend 4 pages.
# La publication date du 12.08.1869 et comprend 4 pages.
# La publication date du 13.08.1869 et comprend 4 pages.
# La publication date du 14.08.1869 et comprend 4 pages.
# La publication date du 15.08.1869 et comprend 4 pages.
# La publication date du 16.08.1869 et comprend 4 pages.
# La publication date du 17.08.1869 et comprend 4 pages.
# La publication date du 18.08.1869 et comprend 4 pages.
# La publication date du 19.08.1869 et comprend 4 pages.
# La publication date du 20.08.1869 et comprend 4 pages.
# La publication date du 21.08.1869 et comprend 4 pages.
# La publication date du 22.08.1869 et comprend 4 pages.
# La publication date du 23.08.1869 et comprend 4 pages.
# La publication date du 24.08.1869 et comprend 4 pages.
# La publication date du 25.08.1869 et comprend 4 pages.
# La publication date du 26.08.1869 et comprend 4 pages.
# La publication date du 27.08.1869 et comprend 4 pages.
# La publication date du 28.08.1869 et comprend 4 pages.
# La publication date du 29.08.1869 et comprend 4 pages.
# La publication date du 30.08.1869 et comprend 4 pages.
# La publication date du 31.08.1869 et comprend 4 pages.
# La publication date du 01.09.1869 et comprend 4 pages.
# La publication date du 02.09.1869 et comprend 4 pages.
# La publication date du 03.09.1869 et comprend 4 pages.
# La publication date du 04.09.1869 et comprend 4 pages.
# La publication date du 05.09.1869 et comprend 4 pages.
# La publication date du 06.09.1869 et comprend 4 pages.
# La publication date du 07.09.1869 et comprend 4 pages.
# La publication date du 08.09.1869 et comprend 4 pages.
# La publication date du 09.09.1869 et comprend 4 pages.
# La publication date du 10.09.1869 et comprend 4 pages.
# La publication date du 11.09.1869 et comprend 4 pages.
# La publication date du 12.09.1869 et comprend 4 pages.
# La publication date du 13.09.1869 et comprend 4 pages.
# La publication date du 14.09.1869 et comprend 4 pages.
# La publication date du 15.09.1869 et comprend 4 pages.
# La publication date du 16.09.1869 et comprend 4 pages.
# La publication date du 17.09.1869 et comprend 4 pages.
# La publication date du 18.09.1869 et comprend 4 pages.
# La publication date du 19.09.1869 et comprend 4 pages.
# La publication date du 20.09.1869 et comprend 4 pages.
# La publication date du 21.09.1869 et comprend 4 pages.
# La publication date du 22.09.1869 et comprend 4 pages.
# La publication date du 23.09.1869 et comprend 4 pages.
# La publication date du 24.09.1869 et comprend 4 pages.
# La publication date du 25.09.1869 et comprend 4 pages.
# La publication date du 26.09.1869 et comprend 4 pages.
# La publication date du 27.09.1869 et comprend 4 pages.
# La publication date du 28.09.1869 et comprend 4 pages.
# La publication date du 29.09.1869 et comprend 4 pages.
# La publication date du 30.09.1869 et comprend 4 pages.
# La publication date du 01.10.1869 et comprend 4 pages.
# La publication date du 02.10.1869 et comprend 4 pages.
# La publication date du 03.10.1869 et comprend 4 pages.
# La publication date du 04.10.1869 et comprend 4 pages.
# La publication date du 05.10.1869 et comprend 4 pages.
# La publication date du 06.10.1869 et comprend 4 pages.
# La publication date du 07.10.1869 et comprend 4 pages.
# La publication date du 08.10.1869 et comprend 4 pages.
# La publication date du 09.10.1869 et comprend 4 pages.
# La publication date du 10.10.1869 et comprend 4 pages.
# La publication date du 11.10.1869 et comprend 4 pages.
# La publication date du 12.10.1869 et comprend 4 pages.
# La publication date du 13.10.1869 et comprend 4 pages.
# La publication date du 14.10.1869 et comprend 4 pages.
# La publication date du 15.10.1869 et comprend 4 pages.
# La publication date du 16.10.1869 et comprend 4 pages.
# La publication date du 17.10.1869 et comprend 4 pages.
# La publication date du 18.10.1869 et comprend 4 pages.
# La publication date du 19.10.1869 et comprend 4 pages.
# La publication date du 20.10.1869 et comprend 4 pages.
# La publication date du 21.10.1869 et comprend 4 pages.
# La publication date du 22.10.1869 et comprend 4 pages.
# La publication date du 23.10.1869 et comprend 4 pages.
# La publication date du 24.10.1869 et comprend 4 pages.
# La publication date du 25.10.1869 et comprend 4 pages.
# La publication date du 26.10.1869 et comprend 4 pages.
# La publication date du 27.10.1869 et comprend 4 pages.
# La publication date du 28.10.1869 et comprend 4 pages.
# La publication date du 29.10.1869 et comprend 4 pages.
# La publication date du 30.10.1869 et comprend 4 pages.
# La publication date du 31.10.1869 et comprend 4 pages.
# La publication date du 01.11.1869 et comprend 4 pages.
# La publication date du 02.11.1869 et comprend 4 pages.
# La publication date du 03.11.1869 et comprend 4 pages.
# La publication date du 04.11.1869 et comprend 4 pages.
# La publication date du 05.11.1869 et comprend 4 pages.
# La publication date du 06.11.1869 et comprend 4 pages.
# La publication date du 07.11.1869 et comprend 4 pages.
# La publication date du 08.11.1869 et comprend 4 pages.
# La publication date du 09.11.1869 et comprend 4 pages.
# La publication date du 10.11.1869 et comprend 4 pages.
# La publication date du 11.11.1869 et comprend 4 pages.
# La publication date du 12.11.1869 et comprend 4 pages.
# La publication date du 13.11.1869 et comprend 4 pages.
# La publication date du 14.11.1869 et comprend 4 pages.
# La publication date du 15.11.1869 et comprend 4 pages.
# La publication date du 16.11.1869 et comprend 4 pages.
# La publication date du 17.11.1869 et comprend 4 pages.
# La publication date du 18.11.1869 et comprend 4 pages.
# La publication date du 19.11.1869 et comprend 4 pages.
# La publication date du 20.11.1869 et comprend 4 pages.
# La publication date du 21.11.1869 et comprend 4 pages.
# La publication date du 22.11.1869 et comprend 4 pages.
# La publication date du 23.11.1869 et comprend 4 pages.
# La publication date du 24.11.1869 et comprend 4 pages.
# La publication date du 25.11.1869 et comprend 4 pages.
# La publication date du 26.11.1869 et comprend 4 pages.
# La publication date du 27.11.1869 et comprend 4 pages.
# La publication date du 28.11.1869 et comprend 4 pages.
# La publication date du 29.11.1869 et comprend 4 pages.
# La publication date du 29.11.1869 et comprend 1 pages.
# La publication date du 30.11.1869 et comprend 4 pages.
# La publication date du 01.12.1869 et comprend 4 pages.
# La publication date du 02.12.1869 et comprend 4 pages.
# La publication date du 03.12.1869 et comprend 4 pages.
# La publication date du 03.12.1869 et comprend 2 pages.
# La publication date du 04.12.1869 et comprend 4 pages.
# La publication date du 05.12.1869 et comprend 4 pages.
# La publication date du 06.12.1869 et comprend 4 pages.
# La publication date du 06.12.1869 et comprend 2 pages.
# La publication date du 07.12.1869 et comprend 4 pages.
# La publication date du 08.12.1869 et comprend 4 pages.
# La publication date du 09.12.1869 et comprend 4 pages.
# La publication date du 10.12.1869 et comprend 4 pages.
# La publication date du 10.12.1869 et comprend 2 pages.
# La publication date du 11.12.1869 et comprend 4 pages.
# La publication date du 12.12.1869 et comprend 4 pages.
# La publication date du 13.12.1869 et comprend 4 pages.
# La publication date du 13.12.1869 et comprend 2 pages.
# La publication date du 14.12.1869 et comprend 4 pages.
# La publication date du 14.12.1869 et comprend 2 pages.
# La publication date du 15.12.1869 et comprend 4 pages.
# La publication date du 16.12.1869 et comprend 4 pages.
# La publication date du 17.12.1869 et comprend 4 pages.
# La publication date du 18.12.1869 et comprend 4 pages.
# La publication date du 19.12.1869 et comprend 4 pages.
# La publication date du 20.12.1869 et comprend 4 pages.
# La publication date du 21.12.1869 et comprend 4 pages.
# La publication date du 22.12.1869 et comprend 4 pages.
# La publication date du 23.12.1869 et comprend 4 pages.
# La publication date du 23.12.1869 et comprend 2 pages.
# La publication date du 24.12.1869 et comprend 4 pages.
# La publication date du 24.12.1869 et comprend 2 pages.
# La publication date du 25.12.1869 et comprend 4 pages.
# La publication date du 26.12.1869 et comprend 4 pages.
# La publication date du 27.12.1869 et comprend 4 pages.
# La publication date du 28.12.1869 et comprend 4 pages.
# La publication date du 29.12.1869 et comprend 4 pages.
# La publication date du 30.12.1869 et comprend 4 pages.
# La publication date du 31.12.1869 et comprend 4 pages.
# La publication date du 01.01.1870 et comprend 4 pages.
# La publication date du 02.01.1870 et comprend 4 pages.
# La publication date du 03.01.1870 et comprend 4 pages.
# La publication date du 04.01.1870 et comprend 4 pages.
# La publication date du 05.01.1870 et comprend 4 pages.
# La publication date du 06.01.1870 et comprend 4 pages.
# La publication date du 07.01.1870 et comprend 4 pages.
# La publication date du 08.01.1870 et comprend 4 pages.
# La publication date du 09.01.1870 et comprend 4 pages.
# La publication date du 10.01.1870 et comprend 4 pages.
# La publication date du 11.01.1870 et comprend 4 pages.
