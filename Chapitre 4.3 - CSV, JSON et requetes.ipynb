# %% [markdown]
# # Chapitre 4.3 - Les fichiers CSV, JSON et les requêtes
#
# ---
#
# ## 1. La structure du web : comment communique-t-on avec un serveur ?
#
# ![Anatomie d'une communication HTTP](images/http.request.scheme.png)
#
# Lors d'une communication HTTP avec un serveur, la communication est divisible en deux : l'envoi de la requête et la réponse du serveur. Ces deux éléments de la communication répondent à un ensemble de standards très stricts permettant le fonctionnement du web tel que nous le connaissons.

# %% [markdown]
# ### 1.A. Anatomie d'une requête :
#
# ![Anatomie d'une requête HTTP](images/http.request.request.png)
#
# La requête, c'est-à-dire l'information envoyée au serveur, est composée à minima de trois types d'informations :
#
# - l'URL
# - la méthode
# - les headers
#
# #### URL
#
# Voir le [schéma](images/url.png) ([Source](https://cascadingmedia.com/assets/images/insites/2015/02/url-anatomy/url-anatomy-55598c24.png)
# L'URL est une information que l'on connait tous. C'est l'adresse dont on requiert le contenu. Typiquement, l'adresse est divisible en plusieurs parties. Celle qui peut être importante et qui changera surement suivant les utilisateurs est la partie *query* qui permet d'apporter des informations supplémentaires.
#
# Par exemple, dans http://cts.dh.uni-leipzig.de/api/cts?request=GetCapabilities&urn=urn:cts:latinLit:phi1294 , on a deux paramètres fournis :
#
# | Nom | Valeur |
# | --- | ------ |
# | urn | urn:cts:latinLit:phi1294 |
# | request | GetCapabilities |
#
# #### Méthode
#
# La méthode informe le serveur de ce que vous allez vouloir faire. 90% des requêtes que vous faites en naviguant sur le web sont en GET : vous récupérez de l'information. Vous utilisez sur les 9.9% restant la requête POST, notamment quand vous vous connectez sur vos comptes sur les divers sites que vous utilisez.
#
# #### Les Headers
#
# Le Header comporte des informations sur vos attentes et votre contexte de requêtage. Par exemple, on peut demander via les Headers un format de réponse particulier (d'après son [mimetype](https://fr.wikipedia.org/wiki/Type_MIME) : html, xml ou json par exemple :
#
# | Headers Clé | Headers Valeur   |
# | ----------- | ---------------- |
# | Accept      | application/json |
#
# #### (Optionnel) Le Corps (Body, data, etc.)
#
# Dans le cadre de l'envoi d'un formulaire ou d'un fichier, on a un corps dans la requête. Beaucoup de formats différents sont possibles dans ce cadre. De nombreuses API acceptent par exemple l'encodage en JSON de vos informations.

# %% [markdown]
# ### 1.B. Anatomie d'une réponse
#
# ![Anatomie d'une réponse HTTP](images/http.request.response.png)
#
# La réponse est composée de trois éléments aussi :
#
# #### Les Headers
#
# Tout comme la requête, les Headers nous renvoient l'information sur la réponse. Voici quelques headers utiles.
#
#
# | Headers Clé | Headers Valeur   | Note |
# | ----------- | ---------------- | ---- |
# | Encoding      | application/json | Type Mime de la réponse |
#
# #### Le code HTTP
#
# Le code HTTP nous informe sur le statut de la réponse. Vous connaissez *à minima* le code 404, qui indique que la ressource demandée n'est pas disponible. Il existe bien d'autres codes (*cf.* [Wikipedia](https://fr.wikipedia.org/wiki/Liste_des_codes_HTTP) :
# - 200 : succès de la requête ;
# - 301 et 302 : redirection, respectivement permanente et temporaire ;
# - 401 : utilisateur non authentifié ;
# - 403 : accès refusé ;
# - 404 : page non trouvée ;
# - 500 et 503 : erreur serveur.
# - 418 : "I’m a teapot" (Blague du 1er avril 1998 restée dans le standard)
#
#
#
# #### Le Corps
#
# Le corps de la réponse contient bien évidemment ce que vous voyez lorsque vous faites une requête : le contenu html, le contenu en plein texte, le contenu json, etc.

# %% [markdown]
# ## 2. Faire des requêtes http en python : le module request
#
#
# ### 2.A Le module `requests`
#
# Tout comme il existe pour python des modules pour gérer les CSV et les JSON, il en existe pour faire des requêtes WEB. Cela dit, ils ne font pas partie du coeur de Python ! C'est pour ça que nous les avons installés. En effet, quant à l'installation, vous avez tapé `pip install -r requirements.txt`, vous avez demandé à PIP (un gestionnaire de dépendances/librairies de python) d'installer chaque librairie citée dans le fichier `requirements.txt`. L'une d'entre elles était `requests`
#
# Le module `requests` possède sa documentation sur son [propre site](http://docs.python-requests.org/en/master/). Au moment de l'écriture, le module est dans sa version 2.18.4.
#
# ### 2.B Faire une requête GET:
#
# Le module est très simple : il propose une fonction `get` qui prend une URL !

# %%
import requests

# Pour l'exemple nous utilisons l'API de Chronicling America, un projet de numérisation de journaux
# Américains
req = requests.get("https://chroniclingamerica.loc.gov/search/pages/results/?format=json&proxtext=ecole+nationale")
print(req)
# Out:
# <Response [200]>

# %% [markdown]
# Les objets `Response` ont plusieurs propriétés intéressantes :
#
# - `.status_code` sous la forme d'un entier qui informe du succès de la requête
# - `.headers` sous la forme d'un dictionnaire qui comporte l'ensemble des headers
# - `.encoding` qui comprend la méthode d'encodage
# - `.text` qui contient le contenu de la réponse
# - `.json()` qui, si `.headers['content-type']` est `application/json`, parse lui-même le json de la réponse.
#
# Voyons un peu leur contenu :

# %%
print(req.status_code)
print(req.headers)
print(req.encoding)
print(req.json)
# Out:
# 200
# {'Date': 'Thu, 24 Oct 2019 05:58:36 GMT', 'Content-Type': 'application/json', 'Content-Length': '187228', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d3b82e166111dccf2ded0ed8bb744f0011571896715; expires=Fri, 23-Oct-20 05:58:35 GMT; path=/; domain=.loc.gov; HttpOnly', 'Last-Modified': 'Wed, 23 Oct 2019 15:58:24 GMT', 'Expires': 'Thu, 24 Oct 2019 15:58:24 GMT', 'Cache-Control': 's-maxage=86400, public, max-age=86400', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'X-requested-with', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Varnish': '92701179 823689461', 'Via': '1.1 varnish (Varnish/5.2)', 'CF-Cache-Status': 'MISS', 'Accept-Ranges': 'bytes', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '52a9b84a3bfbd8c1-AMS'}
# None
# <bound method Response.json of <Response [200]>>

# %%
# Puisque l'on a du json, on peut le traiter comme un dictionnaire ou une liste
# Une rapide ouverture de la page m'informe que le nom du journal est disponible à la clé ""

for resultat in req.json()["items"]:
    print("\"{titre}\" a publié un article comprenant 'école nationale' le {jour}/{mois}/{annee}".format(
        titre=resultat["title_normal"], 
        annee=resultat["date"][:4], 
        mois=resultat["date"][4:6],
        jour=resultat["date"][6:]
    ))
# Out:
# "mississippi enterprise." a publié un article comprenant 'école nationale' le 16/10/1954
# "evening star." a publié un article comprenant 'école nationale' le 27/04/1930
# "washington times." a publié un article comprenant 'école nationale' le 13/11/1921
# "evening star." a publié un article comprenant 'école nationale' le 26/06/1932
# "evening star." a publié un article comprenant 'école nationale' le 10/04/1932
# "evening star." a publié un article comprenant 'école nationale' le 28/06/1931
# "jackson advocate." a publié un article comprenant 'école nationale' le 09/10/1954
# "auttaja." a publié un article comprenant 'école nationale' le 22/11/1951
# "sistersville daily oil review." a publié un article comprenant 'école nationale' le 16/09/1902
# "santa fe new mexican." a publié un article comprenant 'école nationale' le 13/01/1910
# "wenatchee daily world." a publié un article comprenant 'école nationale' le 10/01/1910
# "evening star." a publié un article comprenant 'école nationale' le 04/10/1927
# "weekly thibodaux sentinel and journal of the 8th senatorial district." a publié un article comprenant 'école nationale' le 02/03/1895
# "deutsche correspondent." a publié un article comprenant 'école nationale' le 24/07/1905
# "echo de l'ouest." a publié un article comprenant 'école nationale' le 25/04/1889
# "echo de l'ouest." a publié un article comprenant 'école nationale' le 18/10/1895
# "echo de l'ouest." a publié un article comprenant 'école nationale' le 03/04/1914
# "lake county times." a publié un article comprenant 'école nationale' le 24/05/1910
# "arizona republican." a publié un article comprenant 'école nationale' le 21/02/1917
# "silver messenger." a publié un article comprenant 'école nationale' le 05/04/1910

# %% [markdown]
# La construction d'URL pouvant poser des problèmes (échappement de caractère par exemple), `requests.get()` accepte un paramètre `params`:

# %%
req = requests.get("http://cts.dh.uni-leipzig.de/api/cts", params={
    "urn": "urn:cts:latinLit:phi1294.phi002.perseus-lat2:1.pr.1",
    "request": "GetPassage"
})
print("URL : " + req.url)
if req.status_code == 200:
    print(req.text)
# Out:
# URL : http://cts.dh.uni-leipzig.de/api/cts?urn=urn%3Acts%3AlatinLit%3Aphi1294.phi002.perseus-lat2%3A1.pr.1&request=GetPassage

# %% [markdown]
# De la même manière, la méthode `.get()` accepte des headers sous la forme d'un dictionnaire :

# %%
import requests

# L'adresse suivante permet de demander l'analyse morphologique d'un terme :
url = "http://morph.alpheios.net/api/v1/analysis/word?word=lasciva&lang=lat&engine=whitakerLat"

xml = requests.get(url, headers={"Accept": "text/xml"})
print(xml.text)
req_json = requests.get(url, headers={"Accept": "application/json"})
print(req_json.text)
# Out:
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#   <oac:Annotation xmlns:oac="http://www.openannotation.org/ns/" rdf:about="urn:TuftsMorphologyService:lasciva:whitakerLat">
#     <dcterms:creator xmlns:dcterms="http://purl.org/dc/terms/">
#       <foaf:Agent xmlns:foaf="http://xmlns.com/foaf/0.1/" rdf:about="net.alpheios:tools:wordsxml.v1"/>
#     </dcterms:creator>
#     <dcterms:created xmlns:dcterms="http://purl.org/dc/terms/">2019-10-24T06:02:42.155972</dcterms:created>
#     <dc:rights xmlns:dc="http://purl.org/dc/elements/1.1/">Short definitions and morphology from Words by William Whitaker, Copyright 1993-2007.</dc:rights>
#     <oac:hasTarget>
#       <rdf:Description rdf:about="urn:word:lasciva"/>
#     </oac:hasTarget>
#     <dc:title xmlns:dc="http://purl.org/dc/elements/1.1/"/>
#     <oac:hasBody rdf:resource="urn:uuid:idm140440213196888"/>
#     <oac:Body rdf:about="urn:uuid:idm140440213196888">
#       <rdf:type rdf:resource="cnt:ContentAsXML"/>
#       <cnt:rest xmlns:cnt="http://www.w3.org/2008/content#">
#         <entry>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="7">nominative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="1">vocative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="3">ablative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="7">nominative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="1">vocative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="4">accusative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <dict>
#             <hdwd xml:lang="lat">lascivus, lasciva, lascivum</hdwd>
#             <pofs order="4">adjective</pofs>
#             <freq order="5">frequent</freq>
#           </dict>
#           <mean>playful; lustful, wanton; impudent, mischievous; free from restraint;</mean>
#         </entry>
#       </cnt:rest>
#     </oac:Body>
#   </oac:Annotation>
# </rdf:RDF>
#
# {"RDF": {"Annotation": {"about": "urn:TuftsMorphologyService:lasciva:whitakerLat", "creator": {"Agent": {"about": "net.alpheios:tools:wordsxml.v1"}}, "created": {"$": "2019-10-24T06:02:44.381445"}, "rights": {"$": "Short definitions and morphology from Words by William Whitaker, Copyright 1993-2007."}, "hasTarget": {"Description": {"about": "urn:word:lasciva"}}, "title": {}, "hasBody": {"resource": "urn:uuid:idm140154432900560"}, "Body": {"about": "urn:uuid:idm140154432900560", "type": {"resource": "cnt:ContentAsXML"}, "rest": {"entry": {"infl": [{"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 7, "$": "nominative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 1, "$": "vocative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 3, "$": "ablative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 7, "$": "nominative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 1, "$": "vocative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 4, "$": "accusative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}], "dict": {"hdwd": {"lang": "lat", "$": "lascivus, lasciva, lascivum"}, "pofs": {"order": 4, "$": "adjective"}, "freq": {"order": 5, "$": "frequent"}}, "mean": {"$": "playful; lustful, wanton; impudent, mischievous; free from restraint;"}}}}}}}

# %% [markdown]
# ### 2.C Les autres types de requêtes :
#
# Le module possède de la même manière une méthode `requests.post()` qui prendra en plus un paramètre `data` tout comme il possède les méthodes :
#
# - `.update()`
# - `.delete()`
# - `.put()`
# - `.options()`
#
# Toutes ces requêtes prennent les mêmes paramètres que `.get()`

# %% [markdown]
# ### 2.D Générer une erreur
#
# Imaginons que vous avez un code 404. Vous voulez peut-être éviter de faire tourner un script si cela arrive. L'objet `Response` possède une méthode utile en ce cas : le `.raise_for_status()` :

# %%
import requests 
bad_r = requests.get("http://cts.dh.uni-leipzig.de/collections/urn:cts:froLit")
bad_r.raise_for_status()

# %% [markdown]
# ### Exercice de compréhension
#
# Lisez le code ci-dessous. Il est issu du projet EHRI ( https://portal.ehri-project.eu/api/v1#api-usage-python ). Essayez de comprendre ce qu'il fait, commentez-le de manière à vous en souvenir.

# %%
import requests 

def scope_content(url):
    print("Fetching: " + url)
    r = requests.get(url)
    data = r.json()
    simplified = []

    for item in data["data"]:
        try:
            # fetch the ID and first description...
            identifier = item["id"]
            desc = item["attributes"]["descriptions"][0]
            name = desc["name"]
            scopecontent = desc["scopeAndContent"]
            simplified.append((identifier, scopecontent, name))
        except (IndexError, KeyError) as e:
            # no description or scope and content found... skipping...
            pass

    # fetch the next page of data...
    if data.get("links") and data["links"].get("next"):
        simplified += scope_content(data["links"]["next"])
    return simplified

scope_content("https://portal.ehri-project.eu/api/v1/search?type=DocumentaryUnit&q=Potato")

# %% [markdown]
# ### Exercice de fin de chapitre
#
# 1. Ouvrir http://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/manifest.json
# 2. Comprendre le format de http://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/manifest.json
# 3. En Python, faire une fonction qui prend un identifiant ark BNF et qui:
#     1. Affiche l'ensemble des métadonnées sur l'objet décrit en JSON
#     2. Génère un fichier CSV avec les colonnes `Numéro | Nom de Page | Lien image | Largeur | Longueur` en fonction d'un argument `nom_csv`

# %%
def get_bnf_data(ark):
    url = "http://gallica.bnf.fr/iiif/" + ark + "/manifest.json"
    r = requests.get(url)
    data = r.json()
    return data

def iiif_csv(ark, nom_csv):
    colonnes = ["Numéro", "Nom de Page", "Lien image", "Largeur", "Longueur"]
    # Complétez avec la documentation
    return None

# Testez le code ici
data = get_bnf_data("ark:/12148/btv1b84259980")
data
#iiif_csv("ark:/12148/btv1b84259980", "pages.csv")
# Out:
# {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/manifest.json',
#  'label': 'BnF. Département des manuscrits. Français 412',
#  'attribution': 'Bibliothèque nationale de France',
#  'license': 'https://gallica.bnf.fr/html/und/conditions-dutilisation-des-contenus-de-gallica',
#  'logo': 'https://gallica.bnf.fr/mbImage/logos/logo-bnf.png',
#  'related': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980',
#  'seeAlso': ['http://oai.bnf.fr/oai2/OAIHandler?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:bnf.fr:gallica/ark:/12148/btv1b84259980'],
#  'description': 'Recueil de textes , Vie de saints',
#  'metadata': [{'label': 'Repository', 'value': ''},
#   {'label': 'Digitised by', 'value': 'Bibliothèque nationale de France'},
#   {'label': 'Source Images',
#    'value': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980'},
#   {'label': 'Metadata Source',
#    'value': 'http://oai.bnf.fr/oai2/OAIHandler?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:bnf.fr:gallica/ark:/12148/btv1b84259980'},
#   {'label': 'Shelfmark',
#    'value': 'Bibliothèque nationale de France. Département des manuscrits. Français 412'},
#   {'label': 'Title', 'value': 'Recueil de textes , Vie de saints'},
#   {'label': 'Date', 'value': '1285'},
#   {'label': 'Language', 'value': 'français'},
#   {'label': 'Format', 'value': 'Vélin, miniatures, lettres ornées'},
#   {'label': 'Relation',
#    'value': 'Notice du catalogue : http://archivesetmanuscrits.bnf.fr/ark:/12148/cc50522d'},
#   {'label': 'Type', 'value': 'Manuscrit'}],
#  'sequences': [{'canvases': [{'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f1',
#      'label': 'plat supérieur',
#      'height': 5707,
#      'width': 4170,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f1',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f1'},
#         'height': 5707,
#         'width': 4170,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f1/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f1.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f2',
#      'label': 'contreplat sup.',
#      'height': 5704,
#      'width': 4104,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f2',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f2'},
#         'height': 5704,
#         'width': 4104,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f2/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f2.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f3',
#      'label': 'page de garde recto',
#      'height': 5591,
#      'width': 3927,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f3',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f3'},
#         'height': 5591,
#         'width': 3927,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f3/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f3.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f4',
#      'label': 'page de garde verso',
#      'height': 5641,
#      'width': 4037,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f4',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f4'},
#         'height': 5641,
#         'width': 4037,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f4/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f4.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f5',
#      'label': 'page de garde recto',
#      'height': 5591,
#      'width': 3927,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f5',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f5'},
#         'height': 5591,
#         'width': 3927,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f5/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f5.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f6',
#      'label': 'page de garde verso',
#      'height': 5641,
#      'width': 4037,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f6',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f6'},
#         'height': 5641,
#         'width': 4037,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f6/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f6.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f7',
#      'label': 'page de garde recto',
#      'height': 5591,
#      'width': 3927,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f7',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f7'},
#         'height': 5591,
#         'width': 3927,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f7/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f7.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f8',
#      'label': 'page de garde verso',
#      'height': 5641,
#      'width': 4025,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f8',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f8'},
#         'height': 5641,
#         'width': 4025,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f8/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f8.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f9',
#      'label': 'page de garde recto',
#      'height': 5521,
#      'width': 3907,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f9',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f9'},
#         'height': 5521,
#         'width': 3907,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f9/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f9.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f10',
#      'label': 'page de garde verso',
#      'height': 5584,
#      'width': 4025,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f10',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f10'},
#         'height': 5584,
#         'width': 4025,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f10/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f10.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f11',
#      'label': '1r',
#      'height': 5521,
#      'width': 3816,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f11',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f11'},
#         'height': 5521,
#         'width': 3816,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f11/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f11.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f12',
#      'label': '1v',
#      'height': 5592,
#      'width': 3872,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f12',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f12'},
#         'height': 5592,
#         'width': 3872,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f12/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f12.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f13',
#      'label': '2r',
#      'height': 5550,
#      'width': 3820,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f13',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f13'},
#         'height': 5550,
#         'width': 3820,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f13/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f13.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f14',
#      'label': '2v',
#      'height': 5592,
#      'width': 3872,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f14',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f14'},
#         'height': 5592,
#         'width': 3872,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f14/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f14.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f15',
#      'label': '3r',
#      'height': 5550,
#      'width': 3820,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f15',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f15'},
#         'height': 5550,
#         'width': 3820,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f15/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f15.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f16',
#      'label': '3v',
#      'height': 5656,
#      'width': 3904,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f16',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f16'},
#         'height': 5656,
#         'width': 3904,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f16/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f16.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f17',
#      'label': '4r',
#      'height': 5550,
#      'width': 3820,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f17',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f17'},
#         'height': 5550,
#         'width': 3820,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f17/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f17.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f18',
#      'label': '4v',
#      'height': 5656,
#      'width': 3892,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f18',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f18'},
#         'height': 5656,
#         'width': 3892,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f18/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f18.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f19',
#      'label': '5r',
#      'height': 5535,
#      'width': 3820,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f19',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f19'},
#         'height': 5535,
#         'width': 3820,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f19/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f19.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f20',
#      'label': '5v',
#      'height': 5640,
#      'width': 3904,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f20',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f20'},
#         'height': 5640,
#         'width': 3904,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f20/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f20.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f21',
#      'label': '6r',
#      'height': 5535,
#      'width': 3805,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f21',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f21'},
#         'height': 5535,
#         'width': 3805,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f21/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f21.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f22',
#      'label': '6v',
#      'height': 5640,
#      'width': 3904,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f22',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f22'},
#         'height': 5640,
#         'width': 3904,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f22/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f22.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f23',
#      'label': '7r',
#      'height': 5535,
#      'width': 3805,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f23',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f23'},
#         'height': 5535,
#         'width': 3805,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f23/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f23.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f24',
#      'label': '7v',
#      'height': 5640,
#      'width': 3889,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f24',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f24'},
#         'height': 5640,
#         'width': 3889,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f24/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f24.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f25',
#      'label': '8r',
#      'height': 5535,
#      'width': 3805,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f25',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f25'},
#         'height': 5535,
#         'width': 3805,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f25/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f25.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f26',
#      'label': '8v',
#      'height': 5640,
#      'width': 3889,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f26',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f26'},
#         'height': 5640,
#         'width': 3889,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f26/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f26.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f27',
#      'label': '9r',
#      'height': 5535,
#      'width': 3805,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f27',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f27'},
#         'height': 5535,
#         'width': 3805,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f27/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f27.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f28',
#      'label': '9v',
#      'height': 5640,
#      'width': 3873,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f28',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f28'},
#         'height': 5640,
#         'width': 3873,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f28/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f28.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f29',
#      'label': '10r',
#      'height': 5535,
#      'width': 3831,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f29',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f29'},
#         'height': 5535,
#         'width': 3831,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f29/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f29.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f30',
#      'label': '10v',
#      'height': 5640,
#      'width': 3873,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f30',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f30'},
#         'height': 5640,
#         'width': 3873,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f30/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f30.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f31',
#      'label': '11r',
#      'height': 5547,
#      'width': 3831,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f31',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f31'},
#         'height': 5547,
#         'width': 3831,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f31/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f31.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f32',
#      'label': '11v',
#      'height': 5640,
#      'width': 3873,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f32',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f32'},
#         'height': 5640,
#         'width': 3873,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f32/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f32.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f33',
#      'label': '12r',
#      'height': 5547,
#      'width': 3831,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f33',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f33'},
#         'height': 5547,
#         'width': 3831,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f33/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f33.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f34',
#      'label': '12v',
#      'height': 5640,
#      'width': 3848,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f34',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f34'},
#         'height': 5640,
#         'width': 3848,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f34/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f34.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f35',
#      'label': '13r',
#      'height': 5553,
#      'width': 3831,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f35',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f35'},
#         'height': 5553,
#         'width': 3831,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f35/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f35.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f36',
#      'label': '13v',
#      'height': 5640,
#      'width': 3873,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f36',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f36'},
#         'height': 5640,
#         'width': 3873,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f36/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f36.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f37',
#      'label': '14r',
#      'height': 5547,
#      'width': 3817,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f37',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f37'},
#         'height': 5547,
#         'width': 3817,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f37/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f37.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f38',
#      'label': '14v',
#      'height': 5640,
#      'width': 3825,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f38',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f38'},
#         'height': 5640,
#         'width': 3825,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f38/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f38.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f39',
#      'label': '15r',
#      'height': 5535,
#      'width': 3817,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f39',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f39'},
#         'height': 5535,
#         'width': 3817,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f39/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f39.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f40',
#      'label': '15v',
#      'height': 5640,
#      'width': 3842,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f40',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f40'},
#         'height': 5640,
#         'width': 3842,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f40/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f40.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f41',
#      'label': '16r',
#      'height': 5535,
#      'width': 3798,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f41',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f41'},
#         'height': 5535,
#         'width': 3798,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f41/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f41.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f42',
#      'label': '16v',
#      'height': 5640,
#      'width': 3842,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f42',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f42'},
#         'height': 5640,
#         'width': 3842,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f42/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f42.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f43',
#      'label': '17r',
#      'height': 5535,
#      'width': 3798,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f43',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f43'},
#         'height': 5535,
#         'width': 3798,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f43/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f43.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f44',
#      'label': '17v',
#      'height': 5640,
#      'width': 3836,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f44',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f44'},
#         'height': 5640,
#         'width': 3836,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f44/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f44.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f45',
#      'label': '18r',
#      'height': 5535,
#      'width': 3799,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f45',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f45'},
#         'height': 5535,
#         'width': 3799,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f45/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f45.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f46',
#      'label': '18v',
#      'height': 5640,
#      'width': 3836,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f46',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f46'},
#         'height': 5640,
#         'width': 3836,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f46/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f46.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f47',
#      'label': '19r',
#      'height': 5590,
#      'width': 3835,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f47',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f47'},
#         'height': 5590,
#         'width': 3835,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f47/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f47.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f48',
#      'label': '19v',
#      'height': 5640,
#      'width': 3869,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f48',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f48'},
#         'height': 5640,
#         'width': 3869,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f48/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f48.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f49',
#      'label': '20r',
#      'height': 5590,
#      'width': 3835,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f49',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f49'},
#         'height': 5590,
#         'width': 3835,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f49/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f49.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f50',
#      'label': '20v',
#      'height': 5640,
#      'width': 3869,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f50',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f50'},
#         'height': 5640,
#         'width': 3869,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f50/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f50.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f51',
#      'label': '21r',
#      'height': 5590,
#      'width': 3835,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f51',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f51'},
#         'height': 5590,
#         'width': 3835,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f51/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f51.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f52',
#      'label': '21v',
#      'height': 5606,
#      'width': 3823,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f52',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f52'},
#         'height': 5606,
#         'width': 3823,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f52/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f52.thumbnail'},
#      '@type': 'sc:Canvas'},
# ...
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f497.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f498',
#      'label': '244v',
#      'height': 5669,
#      'width': 3859,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f498',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f498'},
#         'height': 5669,
#         'width': 3859,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f498/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f498.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f499',
#      'label': '245r',
#      'height': 5674,
#      'width': 3814,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f499',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f499'},
#         'height': 5674,
#         'width': 3814,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f499/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f499.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f500',
#      'label': '245v',
#      'height': 5644,
#      'width': 3836,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f500',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f500'},
#         'height': 5644,
#         'width': 3836,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f500/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f500.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f501',
#      'label': 'page de garde recto',
#      'height': 5630,
#      'width': 3939,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f501',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f501'},
#         'height': 5630,
#         'width': 3939,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f501/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f501.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f502',
#      'label': 'page de garde verso',
#      'height': 5628,
#      'width': 3876,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f502',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f502'},
#         'height': 5628,
#         'width': 3876,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f502/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f502.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f503',
#      'label': 'page de garde recto',
#      'height': 5630,
#      'width': 3939,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f503',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f503'},
#         'height': 5630,
#         'width': 3939,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f503/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f503.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f504',
#      'label': 'page de garde verso',
#      'height': 5628,
#      'width': 3888,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f504',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f504'},
#         'height': 5628,
#         'width': 3888,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f504/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f504.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f505',
#      'label': 'page de garde recto',
#      'height': 5630,
#      'width': 3939,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f505',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f505'},
#         'height': 5630,
#         'width': 3939,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f505/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f505.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f506',
#      'label': 'page de garde verso',
#      'height': 5628,
#      'width': 3951,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f506',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f506'},
#         'height': 5628,
#         'width': 3951,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f506/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f506.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f507',
#      'label': 'page de garde recto',
#      'height': 5630,
#      'width': 3960,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f507',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f507'},
#         'height': 5630,
#         'width': 3960,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f507/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f507.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f508',
#      'label': 'page de garde verso',
#      'height': 5628,
#      'width': 3951,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f508',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f508'},
#         'height': 5628,
#         'width': 3951,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f508/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f508.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f509',
#      'label': 'contreplat inf.',
#      'height': 5716,
#      'width': 4154,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f509',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f509'},
#         'height': 5716,
#         'width': 4154,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f509/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f509.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f510',
#      'label': 'plat inférieur.',
#      'height': 5805,
#      'width': 4256,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f510',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f510'},
#         'height': 5805,
#         'width': 4256,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f510/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f510.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f511',
#      'label': 'dos',
#      'height': 5666,
#      'width': 1173,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f511',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f511'},
#         'height': 5666,
#         'width': 1173,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f511/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f511.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f512',
#      'label': 'tranche supérieure',
#      'height': 1692,
#      'width': 4297,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f512',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f512'},
#         'height': 1692,
#         'width': 4297,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f512/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f512.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f513',
#      'label': 'gouttière',
#      'height': 5651,
#      'width': 1620,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f513',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f513'},
#         'height': 5651,
#         'width': 1620,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f513/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f513.thumbnail'},
#      '@type': 'sc:Canvas'},
#     {'@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f514',
#      'label': 'tranche inférieure',
#      'height': 1608,
#      'width': 4273,
#      'images': [{'motivation': 'sc:painting',
#        'on': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/canvas/f514',
#        'resource': {'format': 'image/jpeg',
#         'service': {'profile': 'http://library.stanford.edu/iiif/image-api/1.1/compliance.html#level2',
#          '@context': 'http://iiif.io/api/image/1/context.json',
#          '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f514'},
#         'height': 1608,
#         'width': 4273,
#         '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/f514/full/full/0/native.jpg',
#         '@type': 'dctypes:Image'},
#        '@type': 'oa:Annotation'}],
#      'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980/f514.thumbnail'},
#      '@type': 'sc:Canvas'}],
#    'label': 'Current Page Order',
#    '@type': 'sc:Sequence',
#    '@id': 'https://gallica.bnf.fr/iiif/ark:/12148/btv1b84259980/sequence/default'}],
#  'thumbnail': {'@id': 'https://gallica.bnf.fr/ark:/12148/btv1b84259980.thumbnail'},
#  '@type': 'sc:Manifest',
#  '@context': 'http://iiif.io/api/presentation/2/context.json'}

# %% [markdown]
# ----
#
# #### Ce que l'on a appris
#
# Pour finir cette section, voici un récapitulatif des concepts appris. Lisez la liste et posez des questions si certaines choses ne sont pas claires.
#
# - la structure d'une requête http et de sa réponse
# - `requests.get`
# - `requests.post` et les autres
# - `Response.json()`
# - `Response.status_code`
# - `Response.text`
# - `Response.headers`
# - `Response.raise_for_status()`
